# %% [markdown]
# # General information
# **Content**
# + some words about myself
# + structure of the course
#     + general organisation (timing, slack, credits, course website)
#     + content outline
#     + final project
# + tools that we will use
#     + Anaconda (some words about current situation)
#         + JupyterLab
#         + Spyder
#     + Git, Git Bash & GitHub
# + interesting resources/communities
#
# ## Structure of the course
# ### General info
# + dates: 22.08. - 28./29.08.
# + time: 9.00 - 12.00 / 13.00 - 15.00/16.00
# + general info about the course can be found
#     + slack (orga, Q&A, resources, group channels)
#     + course website (Link)
# + successful participation: 3 Credits
# + grading based on final project (see below)
#
# ### Final project
# + select a problem (e.g., data analysis, implementation of an algorithm (e.g., EM-algorithm), solving a logical problem (e.g. from ProjectEuler))
# + workout structure of your problem and task/subtasks that need to be accomplished (which will be equiv. to your functions/classes)
# + create a git repo for version control
# + push/pull your work to GitHub for collaborative work
# + create a Python package incorporating all required functions/classes
# + install your Python package locally
# + create a jupyternotebook in which
#     + you import your own module and (all necessary additional moAAdules)
#     + introduce/describe your module
#     + create a little tutorial in which you show how your module works using examples
#
# ## Tools that we will use
#
# ### Anaconda, conda, & pip
# + convenient environment and package manager: comes already with a lot of tools that we will use (such as Spyder, Jupyterlab, etc.)
# + easy creation of **environments** to organise your projects
# + in the future I will change to [`mamba`](https://mamba.readthedocs.io/en/latest/installation/mamba-installation.html)
# + Ananconda changed their Terms of Services (see e.g. [this Twitter-Thread](https://www.theregister.com/2024/08/08/anaconda_puts_the_squeeze_on/))
#     + main issue: non profit organisations with more that 200 employees need to buy commercial licenses (result: most institutes will ban anaconda and use alternatives such as mamba)
#
# **Installing packages via `conda` and `pip`**
# + when we want to install a module via Anaconda's package manager we use `conda`
# + `pip` can install anything from the [Python Package Index (`PyPI`)](https://pypi.org/) which is a repository of software for the Python programming language (equivalent to CRAN in R)
# + `pip` vs. `conda`
#     + pip installs Python packages
#     + conda installs packages which may contain software written in any language. (For example, before using pip, a Python interpreter must be installed via a system package manager or by downloading and running an installer. Conda on the other hand can install Python packages as well as the Python interpreter directly.)
#     + Occasionally a package is needed which is not available as a conda package but is available on PyPI and can be installed with pip. In these cases, it makes sense to try to use both conda and pip.
#
# ### JupyterLab
# + (equivalent to Rmarkdown)
# + [`JupyterLab`](https://jupyter.org/) is a web-based interactive development environment for notebooks, code, and data.
# + very helpful for combining text, code, and visualizations
# + we will work mainly with JupyterLab during our course
# + for the final project I recommend you to use JuypterLab as docummentation/tutorial for your Python package
#
# ### Spyder
# + (equivalent to RStudio)
# + **IDE** (integrated development environment)
# + [`Spyder`](https://www.spyder-ide.org/) is a free and open source scientific environment written in Python, for Python
# + alternatives are e.g., [`VSCode`](https://code.visualstudio.com/), [`PyCharm`](https://www.jetbrains.com/de-de/pycharm/)
# + useful for writing scripts
# + we will use Spyder when we write functions/classes for our Python package
#
# ### Git, Git Bash, & GitHub
# + [`Git`](https://git-scm.com/) for version control
#     + Version control is a system that records changes to a file or set of files over time so that you can recall specific versions later
#     + Git is a system that supports you in tracking and tracing the history of your files
# + to run Git in Windows from the command line we need [`Git Bash`](https://gitforwindows.org/)
#     + GitBash is an application for Microsoft Windows environments which provides an emulation layer for a Git command line experience.
#     + We can install it directly, but it comes also directly when we use GitHub Desktop
# + [`GitHub`](https://github.com/) for collaborative work; sharing your work with the community & backup
#     + GitHub is a platform that provides you to share your work with others or also to be easily accessible from different devices
# + an easy integration of Git and GitHub is provided by [`GitHub Desktop`](https://github.com/apps/desktop)
#     + GitHub Desktop is a Git client for streamlining and enhancing your local code management process
#
# ## Interesting resources / communities
# + [ThinkPython](https://allendowney.github.io/ThinkPython/) [book]
#   > Think Python is an introduction to Python programming for beginners. It starts with basic concepts of programming; it is carefully designed to define all terms when they are first used and to develop each new concept in a logical progression.
# + [Fluent Python](https://www.oreilly.com/library/view/fluent-python-2nd/9781492056348/) [book]
#   > more advanced approach to Python programming
# + [The Turing Way](https://book.the-turing-way.org/) [community]
#   > The Turing Way is an open science, open collaboration, and community-driven project. We involve and support a diverse community of contributors to make data science accessible, comprehensible and effective for everyone. Our goal is to provide all the information that researchers, data scientists, software engineers, policymakers, and other practitioners in academia, industry, government and the public sector need to ensure that the projects they work on are easy to reproduce and reuse.
# + [de-RSE - Research Software Engineers](https://de-rse.org/de/index.html) [community]
#   > Researchers, scientists and others developing software in and for research within the German scientific landscape have come together in the de-RSE community in order to considerably boost the visibility of "these" (see website link) issues, and to decisively improve the current situation. de-RSE aims at constituting a wider initiative for acting jointly on shared objectives, and being the collective spokesperson for RSEs within the German scientific landscape.
# + [The Carpentries](https://carpentries.org/) [education]
#   > The Carpentries project comprises the Software Carpentry, Data Carpentry, and Library Carpentry communities of Instructors, Trainers, Maintainers, helpers, and supporters who share a mission to teach foundational computational and data science skills to researchers.
# + [Code for thought](https://codeforthought.buzzsprout.com/) [podcast]
#   > community podcast for research software engineers and researchers who code.  Languages: English, German
# + [PyCon](https://2024.pycon.de/) [conference; [talks on YouTube](https://www.youtube.com/user/PyConDE)]
#   > We aim to be an accessible, community-driven conference, with novice to advanced level presentations. Tutorials and talks bring attendees the latest project features along with cutting-edge use cases. The conference is organised by experts for other experts providing an excellent quality level of content. Newcomers explictly welcome!
# + [PyLadies](https://pyladies.com/) [community]
#   > We are an international mentorship group with a focus on helping more women become active participants and leaders in the Python open-source community. Our mission is to promote, educate and advance a diverse Python community through outreach, education, conferences, events and social gatherings.

# %%
from IPython.display import Image
from IPython.core.display import HTML 

PATH = "material/graphics/"
Image(filename = PATH + "system-tools.png", width=800)

# %% [markdown]
# ## Create a Python environment
# + open **Anaconda**, go to **Environments**, click on **create**, and give the environment a name: "python-course-2024-env"
# + alternatively, use the command window:

# %%
% GitBash
# create conda environment (using command line)
$ conda create -n python-course-2024-env

# %% [markdown]
# ## Create a Git repository
#
# + open **GitHub Desktop** and create a new repository
#     + Name: "python-course-2024"
#     + Description: "Introduction in Python summer term 2024"
#     + Initialize Repo with README: True
#     + License: MIT
# + confirm changes using **Create repository**
# + go to the tap **Repository** and click on **Open in GitBash** (a commmand window should open)
#     + activate your environment

# %%
% GitBash
# activate environment
$ conda activate python-course-2024-env

# %% [markdown]
# ## Let's get started...
# + open **Anaconda** > **Home**
# + select in the drop-down menu the corresponding environment: *python-course-2024-env*
# + **install JupyterLab**
# + once JupyterLab is installed, you can **launch** it and your default browser will open
# + now we can start creating our first Jupyter notebook
#
# Helpful references for working with JupyterLab:
# + [Markdown for Jupyter notebooks cheatsheet](https://www.ibm.com/docs/en/watson-studio-local/1.2.3?topic=notebooks-markdown-jupyter-cheatsheet)
# + [JupyterLab Keyboard Shortcut Cheat Sheet](https://blog.ja-ke.tech/assets/jupyterlab-shortcuts/Shortcuts.png)
